# %%
import pandas as pd
df = pd.read_csv("pokedex_data.csv")

# %%
from IPython.display import display
display(df)
# Out:
#            Nom  National №             Type              Species  \
# 0    Bulbasaur         1.0   Grass | Poison         Seed Pokémon
# 1      Ivysaur         2.0   Grass | Poison         Seed Pokémon
# 2     Venusaur         3.0   Grass | Poison         Seed Pokémon
# 3   Charmander         4.0             Fire       Lizard Pokémon
# 4   Charmeleon         5.0             Fire        Flame Pokémon
# 5    Charizard         6.0    Fire | Flying        Flame Pokémon
# 6     Squirtle         7.0            Water  Tiny Turtle Pokémon
# 7    Wartortle         8.0            Water       Turtle Pokémon
# 8    Blastoise         9.0            Water    Shellfish Pokémon
# 9     Caterpie        10.0              Bug         Worm Pokémon
# 10     Metapod        11.0              Bug       Cocoon Pokémon
# 11  Butterfree        12.0     Bug | Flying    Butterfly Pokémon
# 12      Weedle        13.0     Bug | Poison    Hairy Bug Pokémon
# ...
